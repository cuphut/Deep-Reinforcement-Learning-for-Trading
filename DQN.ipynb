# %%
# !pip install tensorflow
# !pip install stable_baselines3
# !pip install gym
# !pip install gym-anytrading
# !pip install tensorflow-gpu

# %%
# Gym stuff
import gymnasium as gym
import gym_anytrading

# Stable baselines - RL stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import DQN
# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# Load GME trading data
df = pd.read_csv('gmedata.csv')

# Convert data to datetime type
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes

# Set Date as the index
df.set_index('Date', inplace=True)
df.head()
# Out:
#               Open    High     Low  Close      Volume
# Date
# 2021-03-12  275.00  295.50  262.27  264.5  25,845,900
# 2021-03-11  241.64  281.50  232.60  260.0  28,312,490
# 2021-03-10  269.43  348.50  172.00  265.0  71,570,570
# 2021-03-09  217.71  249.85  208.51  246.9  39,099,328
# 2021-03-08  154.89  210.87  146.10  194.5  63,565,621

# %%
# Create the environment
env = gym.make('stocks-v0', df=df, frame_bound=(5, 100), window_size=5)

# Explore the environment
env.action_space
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Discrete(2)

# %%
# View environment features
env.unwrapped.signal_features
# Out:
# array([[ 2.6450e+02,  0.0000e+00],
#        [ 2.6000e+02, -4.5000e+00],
#        [ 2.6500e+02,  5.0000e+00],
#        [ 2.4690e+02, -1.8100e+01],
#        [ 1.9450e+02, -5.2400e+01],
#        [ 1.3774e+02, -5.6760e+01],
#        [ 1.3235e+02, -5.3900e+00],
#        [ 1.2418e+02, -8.1700e+00],
#        [ 1.1818e+02, -6.0000e+00],
#        [ 1.2040e+02,  2.2200e+00],
#        [ 1.0174e+02, -1.8660e+01],
#        [ 1.0873e+02,  6.9900e+00],
#        [ 9.1710e+01, -1.7020e+01],
#        [ 4.4970e+01, -4.6740e+01],
#        [ 4.6000e+01,  1.0300e+00],
#        [ 4.0590e+01, -5.4100e+00],
#        [ 4.0690e+01,  1.0000e-01],
#        [ 4.5940e+01,  5.2500e+00],
#        [ 4.9510e+01,  3.5700e+00],
#        [ 5.2400e+01,  2.8900e+00],
#        [ 5.1100e+01, -1.3000e+00],
#        [ 5.1200e+01,  1.0000e-01],
#        [ 5.0310e+01, -8.9000e-01],
#        [ 6.0000e+01,  9.6900e+00],
#        [ 6.3770e+01,  3.7700e+00],
#        [ 5.3500e+01, -1.0270e+01],
#        [ 9.2410e+01,  3.8910e+01],
#        [ 9.0000e+01, -2.4100e+00],
#        [ 2.2500e+02,  1.3500e+02],
#        [ 3.2500e+02,  1.0000e+02],
#        [ 1.9360e+02, -1.3140e+02],
#        [ 3.4751e+02,  1.5391e+02],
#        [ 1.4798e+02, -1.9953e+02],
#        [ 7.6790e+01, -7.1190e+01],
#        [ 6.5010e+01, -1.1780e+01],
#        [ 4.3030e+01, -2.1980e+01],
#        [ 3.9120e+01, -3.9100e+00],
#        [ 3.9360e+01,  2.4000e-01],
#        [ 3.5500e+01, -3.8600e+00],
#        [ 3.9910e+01,  4.4100e+00],
#        [ 3.1400e+01, -8.5100e+00],
#        [ 1.9950e+01, -1.1450e+01],
#        [ 1.9940e+01, -1.0000e-02],
#        [ 1.7690e+01, -2.2500e+00],
#        [ 1.8080e+01,  3.9000e-01],
#        [ 1.8360e+01,  2.8000e-01],
#        [ 1.7370e+01, -9.9000e-01],
#        [ 1.7250e+01, -1.2000e-01],
#        [ 1.8840e+01,  1.5900e+00],
#        [ 1.9260e+01,  4.2000e-01],
#        [ 1.9380e+01,  1.2000e-01],
#        [ 2.0990e+01,  1.6100e+00],
#        [ 2.0150e+01, -8.4000e-01],
#        [ 2.0570e+01,  4.2000e-01],
#        [ 1.9460e+01, -1.1100e+00],
#        [ 1.5530e+01, -3.9300e+00],
#        [ 1.5630e+01,  1.0000e-01],
#        [ 1.4830e+01, -8.0000e-01],
#        [ 1.3850e+01, -9.8000e-01],
#        [ 1.3850e+01,  0.0000e+00],
#        [ 1.2720e+01, -1.1300e+00],
#        [ 1.3310e+01,  5.9000e-01],
#        [ 1.4120e+01,  8.1000e-01],
#        [ 1.3660e+01, -4.6000e-01],
#        [ 1.6940e+01,  3.2800e+00],
#        [ 1.6350e+01, -5.9000e-01],
#        [ 1.6900e+01,  5.5000e-01],
#        [ 1.6120e+01, -7.8000e-01],
#        [ 1.6580e+01,  4.6000e-01],
#        [ 1.5800e+01, -7.8000e-01],
#        [ 1.6560e+01,  7.6000e-01],
#        [ 1.6080e+01, -4.8000e-01],
#        [ 1.4750e+01, -1.3300e+00],
#        [ 1.3670e+01, -1.0800e+00],
#        [ 1.3900e+01,  2.3000e-01],
#        [ 1.2710e+01, -1.1900e+00],
#        [ 1.2460e+01, -2.5000e-01],
#        [ 1.1570e+01, -8.9000e-01],
#        [ 1.1630e+01,  6.0000e-02],
#        [ 1.2060e+01,  4.3000e-01],
#        [ 1.1010e+01, -1.0500e+00],
#        [ 1.1130e+01,  1.2000e-01],
#        [ 1.1750e+01,  6.2000e-01],
#        [ 1.1100e+01, -6.5000e-01],
#        [ 1.1490e+01,  3.9000e-01],
#        [ 1.1860e+01,  3.7000e-01],
#        [ 1.1450e+01, -4.1000e-01],
#        [ 1.0910e+01, -5.4000e-01],
#        [ 1.1570e+01,  6.6000e-01],
#        [ 1.0750e+01, -8.2000e-01],
#        [ 1.0470e+01, -2.8000e-01],
#        [ 1.1730e+01,  1.2600e+00],
#        [ 1.1820e+01,  9.0000e-02],
#        [ 1.2690e+01,  8.7000e-01],
#        [ 1.3450e+01,  7.6000e-01],
#        [ 1.5000e+01,  1.5500e+00],
#        [ 1.4910e+01, -9.0000e-02],
#        [ 1.4100e+01, -8.1000e-01],
#        [ 1.3860e+01, -2.4000e-01],
#        [ 1.3910e+01,  5.0000e-02]], dtype=float32)

# %%
# View environment prices
env.unwrapped.prices
# Out:
# array([264.5 , 260.  , 265.  , 246.9 , 194.5 , 137.74, 132.35, 124.18,
#        118.18, 120.4 , 101.74, 108.73,  91.71,  44.97,  46.  ,  40.59,
#         40.69,  45.94,  49.51,  52.4 ,  51.1 ,  51.2 ,  50.31,  60.  ,
#         63.77,  53.5 ,  92.41,  90.  , 225.  , 325.  , 193.6 , 347.51,
#        147.98,  76.79,  65.01,  43.03,  39.12,  39.36,  35.5 ,  39.91,
#         31.4 ,  19.95,  19.94,  17.69,  18.08,  18.36,  17.37,  17.25,
#         18.84,  19.26,  19.38,  20.99,  20.15,  20.57,  19.46,  15.53,
#         15.63,  14.83,  13.85,  13.85,  12.72,  13.31,  14.12,  13.66,
#         16.94,  16.35,  16.9 ,  16.12,  16.58,  15.8 ,  16.56,  16.08,
#         14.75,  13.67,  13.9 ,  12.71,  12.46,  11.57,  11.63,  12.06,
#         11.01,  11.13,  11.75,  11.1 ,  11.49,  11.86,  11.45,  10.91,
#         11.57,  10.75,  10.47,  11.73,  11.82,  12.69,  13.45,  15.  ,
#         14.91,  14.1 ,  13.86,  13.91], dtype=float32)

# %%
observation = env.reset(seed=2023)
while True:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    if done:
        print("info", info)
        break

plt.figure(figsize=(15,6))
plt.cla()
env.unwrapped.render_all()
plt.show()
# Out:
# info {'total_reward': 165.2800054550171, 'total_profit': 1.2660997120632607, 'position': <Positions.Long: 1>}

# %%
# Creating our dummy vectorizing environment
env_maker = lambda: gym.make('stocks-v0', df=df, frame_bound=(5, 100), window_size=5)
env = DummyVecEnv([env_maker])

model_DQN = DQN('MlpPolicy', env, verbose=1)
model_DQN.learn(total_timesteps=1000000)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# |    fps              | 822      |
# |    time_elapsed     | 1040     |
# |    total_timesteps  | 855400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.74     |
# |    n_updates        | 201349   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9104     |
# |    fps              | 822      |
# |    time_elapsed     | 1040     |
# |    total_timesteps  | 855776   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12       |
# |    n_updates        | 201443   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9108     |
# |    fps              | 822      |
# |    time_elapsed     | 1040     |
# |    total_timesteps  | 856152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.31     |
# |    n_updates        | 201537   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9112     |
# |    fps              | 822      |
# |    time_elapsed     | 1041     |
# |    total_timesteps  | 856528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.69     |
# |    n_updates        | 201631   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9116     |
# |    fps              | 822      |
# |    time_elapsed     | 1041     |
# |    total_timesteps  | 856904   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.28     |
# |    n_updates        | 201725   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9120     |
# |    fps              | 822      |
# |    time_elapsed     | 1042     |
# |    total_timesteps  | 857280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.57     |
# |    n_updates        | 201819   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9124     |
# |    fps              | 822      |
# |    time_elapsed     | 1042     |
# |    total_timesteps  | 857656   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.1     |
# |    n_updates        | 201913   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9128     |
# |    fps              | 822      |
# |    time_elapsed     | 1043     |
# |    total_timesteps  | 858032   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.81     |
# |    n_updates        | 202007   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9132     |
# |    fps              | 822      |
# |    time_elapsed     | 1043     |
# |    total_timesteps  | 858408   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.64     |
# |    n_updates        | 202101   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9136     |
# |    fps              | 822      |
# |    time_elapsed     | 1044     |
# |    total_timesteps  | 858784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.01     |
# |    n_updates        | 202195   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9140     |
# |    fps              | 822      |
# |    time_elapsed     | 1044     |
# |    total_timesteps  | 859160   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.89     |
# |    n_updates        | 202289   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9144     |
# |    fps              | 822      |
# |    time_elapsed     | 1045     |
# |    total_timesteps  | 859536   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.44     |
# |    n_updates        | 202383   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9148     |
# |    fps              | 822      |
# |    time_elapsed     | 1045     |
# |    total_timesteps  | 859912   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.4     |
# |    n_updates        | 202477   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9152     |
# |    fps              | 822      |
# |    time_elapsed     | 1045     |
# |    total_timesteps  | 860288   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.94     |
# |    n_updates        | 202571   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9156     |
# |    fps              | 822      |
# |    time_elapsed     | 1046     |
# |    total_timesteps  | 860664   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.63     |
# |    n_updates        | 202665   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9160     |
# |    fps              | 822      |
# |    time_elapsed     | 1047     |
# |    total_timesteps  | 861040   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.1      |
# |    n_updates        | 202759   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9164     |
# |    fps              | 822      |
# |    time_elapsed     | 1047     |
# |    total_timesteps  | 861416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.05     |
# |    n_updates        | 202853   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9168     |
# |    fps              | 822      |
# |    time_elapsed     | 1048     |
# |    total_timesteps  | 861792   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42     |
# |    n_updates        | 202947   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9172     |
# |    fps              | 821      |
# |    time_elapsed     | 1049     |
# |    total_timesteps  | 862168   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.87     |
# |    n_updates        | 203041   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9176     |
# |    fps              | 821      |
# |    time_elapsed     | 1049     |
# |    total_timesteps  | 862544   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.51     |
# |    n_updates        | 203135   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9180     |
# |    fps              | 821      |
# |    time_elapsed     | 1049     |
# |    total_timesteps  | 862920   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.4     |
# |    n_updates        | 203229   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9184     |
# |    fps              | 821      |
# |    time_elapsed     | 1050     |
# |    total_timesteps  | 863296   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 18.8     |
# |    n_updates        | 203323   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9188     |
# |    fps              | 821      |
# |    time_elapsed     | 1050     |
# |    total_timesteps  | 863672   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.46     |
# |    n_updates        | 203417   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9192     |
# |    fps              | 821      |
# |    time_elapsed     | 1051     |
# |    total_timesteps  | 864048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.53     |
# |    n_updates        | 203511   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9196     |
# |    fps              | 821      |
# |    time_elapsed     | 1051     |
# |    total_timesteps  | 864424   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.46     |
# |    n_updates        | 203605   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9200     |
# |    fps              | 821      |
# |    time_elapsed     | 1052     |
# |    total_timesteps  | 864800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.63     |
# |    n_updates        | 203699   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9204     |
# |    fps              | 821      |
# |    time_elapsed     | 1052     |
# |    total_timesteps  | 865176   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.98     |
# |    n_updates        | 203793   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9208     |
# |    fps              | 821      |
# |    time_elapsed     | 1052     |
# |    total_timesteps  | 865552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.53     |
# |    n_updates        | 203887   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9212     |
# |    fps              | 822      |
# |    time_elapsed     | 1053     |
# |    total_timesteps  | 865928   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.92     |
# |    n_updates        | 203981   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9216     |
# |    fps              | 822      |
# |    time_elapsed     | 1053     |
# |    total_timesteps  | 866304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2        |
# |    n_updates        | 204075   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9220     |
# |    fps              | 822      |
# |    time_elapsed     | 1054     |
# |    total_timesteps  | 866680   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.42     |
# |    n_updates        | 204169   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9224     |
# |    fps              | 822      |
# |    time_elapsed     | 1054     |
# |    total_timesteps  | 867056   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54     |
# |    n_updates        | 204263   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9228     |
# |    fps              | 822      |
# |    time_elapsed     | 1055     |
# |    total_timesteps  | 867432   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.12     |
# |    n_updates        | 204357   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9232     |
# |    fps              | 822      |
# |    time_elapsed     | 1055     |
# |    total_timesteps  | 867808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12       |
# |    n_updates        | 204451   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9236     |
# |    fps              | 822      |
# |    time_elapsed     | 1056     |
# |    total_timesteps  | 868184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.77     |
# |    n_updates        | 204545   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9240     |
# |    fps              | 822      |
# |    time_elapsed     | 1056     |
# |    total_timesteps  | 868560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65     |
# |    n_updates        | 204639   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9244     |
# |    fps              | 822      |
# |    time_elapsed     | 1057     |
# |    total_timesteps  | 868936   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.61     |
# |    n_updates        | 204733   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9248     |
# |    fps              | 822      |
# |    time_elapsed     | 1057     |
# |    total_timesteps  | 869312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.08     |
# |    n_updates        | 204827   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9252     |
# |    fps              | 822      |
# |    time_elapsed     | 1057     |
# |    total_timesteps  | 869688   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.32     |
# |    n_updates        | 204921   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9256     |
# |    fps              | 822      |
# |    time_elapsed     | 1058     |
# |    total_timesteps  | 870064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.12     |
# |    n_updates        | 205015   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9260     |
# |    fps              | 822      |
# |    time_elapsed     | 1058     |
# |    total_timesteps  | 870440   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.41     |
# |    n_updates        | 205109   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9264     |
# |    fps              | 821      |
# |    time_elapsed     | 1059     |
# |    total_timesteps  | 870816   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.07     |
# |    n_updates        | 205203   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9268     |
# |    fps              | 821      |
# |    time_elapsed     | 1060     |
# |    total_timesteps  | 871192   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.19     |
# |    n_updates        | 205297   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9272     |
# |    fps              | 821      |
# |    time_elapsed     | 1060     |
# |    total_timesteps  | 871568   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.26     |
# |    n_updates        | 205391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9276     |
# |    fps              | 821      |
# |    time_elapsed     | 1061     |
# |    total_timesteps  | 871944   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.85     |
# |    n_updates        | 205485   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9280     |
# |    fps              | 821      |
# |    time_elapsed     | 1061     |
# |    total_timesteps  | 872320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.63     |
# |    n_updates        | 205579   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9284     |
# |    fps              | 821      |
# |    time_elapsed     | 1062     |
# |    total_timesteps  | 872696   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.82     |
# |    n_updates        | 205673   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9288     |
# |    fps              | 821      |
# |    time_elapsed     | 1062     |
# |    total_timesteps  | 873072   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.33     |
# |    n_updates        | 205767   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9292     |
# |    fps              | 821      |
# |    time_elapsed     | 1063     |
# |    total_timesteps  | 873448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.83     |
# |    n_updates        | 205861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9296     |
# |    fps              | 821      |
# |    time_elapsed     | 1063     |
# |    total_timesteps  | 873824   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.58     |
# |    n_updates        | 205955   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9300     |
# |    fps              | 821      |
# |    time_elapsed     | 1064     |
# |    total_timesteps  | 874200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8        |
# |    n_updates        | 206049   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9304     |
# |    fps              | 821      |
# |    time_elapsed     | 1064     |
# |    total_timesteps  | 874576   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.73     |
# |    n_updates        | 206143   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9308     |
# |    fps              | 821      |
# |    time_elapsed     | 1065     |
# |    total_timesteps  | 874952   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.44     |
# |    n_updates        | 206237   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9312     |
# |    fps              | 821      |
# |    time_elapsed     | 1065     |
# |    total_timesteps  | 875328   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.33     |
# |    n_updates        | 206331   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9316     |
# |    fps              | 821      |
# |    time_elapsed     | 1065     |
# |    total_timesteps  | 875704   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.91     |
# |    n_updates        | 206425   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9320     |
# |    fps              | 821      |
# |    time_elapsed     | 1066     |
# |    total_timesteps  | 876080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.34     |
# |    n_updates        | 206519   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9324     |
# |    fps              | 821      |
# |    time_elapsed     | 1066     |
# |    total_timesteps  | 876456   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.95     |
# |    n_updates        | 206613   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9328     |
# |    fps              | 821      |
# |    time_elapsed     | 1067     |
# |    total_timesteps  | 876832   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.73     |
# |    n_updates        | 206707   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9332     |
# |    fps              | 821      |
# |    time_elapsed     | 1067     |
# |    total_timesteps  | 877208   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 206801   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9336     |
# |    fps              | 821      |
# |    time_elapsed     | 1068     |
# |    total_timesteps  | 877584   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9        |
# |    n_updates        | 206895   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9340     |
# |    fps              | 821      |
# |    time_elapsed     | 1068     |
# |    total_timesteps  | 877960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.8     |
# |    n_updates        | 206989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9344     |
# |    fps              | 821      |
# |    time_elapsed     | 1069     |
# |    total_timesteps  | 878336   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.21     |
# |    n_updates        | 207083   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9348     |
# |    fps              | 821      |
# |    time_elapsed     | 1069     |
# |    total_timesteps  | 878712   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.93     |
# |    n_updates        | 207177   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9352     |
# |    fps              | 821      |
# |    time_elapsed     | 1070     |
# |    total_timesteps  | 879088   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.52     |
# |    n_updates        | 207271   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9356     |
# |    fps              | 821      |
# |    time_elapsed     | 1070     |
# |    total_timesteps  | 879464   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.23     |
# |    n_updates        | 207365   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9360     |
# |    fps              | 821      |
# |    time_elapsed     | 1070     |
# |    total_timesteps  | 879840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.89     |
# |    n_updates        | 207459   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9364     |
# |    fps              | 821      |
# |    time_elapsed     | 1071     |
# |    total_timesteps  | 880216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.64     |
# |    n_updates        | 207553   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9368     |
# |    fps              | 821      |
# |    time_elapsed     | 1071     |
# |    total_timesteps  | 880592   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.46     |
# |    n_updates        | 207647   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9372     |
# |    fps              | 821      |
# |    time_elapsed     | 1072     |
# |    total_timesteps  | 880968   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.42     |
# |    n_updates        | 207741   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9376     |
# |    fps              | 821      |
# |    time_elapsed     | 1073     |
# |    total_timesteps  | 881344   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.93     |
# |    n_updates        | 207835   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9380     |
# |    fps              | 821      |
# |    time_elapsed     | 1073     |
# |    total_timesteps  | 881720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.16     |
# |    n_updates        | 207929   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9384     |
# |    fps              | 821      |
# |    time_elapsed     | 1074     |
# |    total_timesteps  | 882096   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.4      |
# |    n_updates        | 208023   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9388     |
# |    fps              | 821      |
# |    time_elapsed     | 1074     |
# |    total_timesteps  | 882472   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78     |
# |    n_updates        | 208117   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9392     |
# |    fps              | 821      |
# |    time_elapsed     | 1075     |
# |    total_timesteps  | 882848   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.81     |
# |    n_updates        | 208211   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9396     |
# |    fps              | 821      |
# |    time_elapsed     | 1075     |
# |    total_timesteps  | 883224   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.75     |
# |    n_updates        | 208305   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9400     |
# |    fps              | 821      |
# |    time_elapsed     | 1076     |
# |    total_timesteps  | 883600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.43     |
# |    n_updates        | 208399   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9404     |
# |    fps              | 821      |
# |    time_elapsed     | 1076     |
# |    total_timesteps  | 883976   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.97     |
# |    n_updates        | 208493   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9408     |
# |    fps              | 821      |
# |    time_elapsed     | 1077     |
# |    total_timesteps  | 884352   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.24     |
# |    n_updates        | 208587   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9412     |
# |    fps              | 821      |
# |    time_elapsed     | 1077     |
# |    total_timesteps  | 884728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.47     |
# |    n_updates        | 208681   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9416     |
# |    fps              | 821      |
# |    time_elapsed     | 1077     |
# |    total_timesteps  | 885104   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 14       |
# |    n_updates        | 208775   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9420     |
# |    fps              | 821      |
# |    time_elapsed     | 1078     |
# |    total_timesteps  | 885480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.51     |
# |    n_updates        | 208869   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9424     |
# |    fps              | 821      |
# |    time_elapsed     | 1078     |
# |    total_timesteps  | 885856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.22     |
# |    n_updates        | 208963   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9428     |
# |    fps              | 821      |
# |    time_elapsed     | 1079     |
# |    total_timesteps  | 886232   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.2     |
# |    n_updates        | 209057   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9432     |
# |    fps              | 821      |
# |    time_elapsed     | 1079     |
# |    total_timesteps  | 886608   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 209151   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9436     |
# |    fps              | 821      |
# |    time_elapsed     | 1080     |
# |    total_timesteps  | 886984   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.46     |
# |    n_updates        | 209245   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9440     |
# |    fps              | 821      |
# |    time_elapsed     | 1080     |
# |    total_timesteps  | 887360   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.08     |
# |    n_updates        | 209339   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9444     |
# |    fps              | 821      |
# |    time_elapsed     | 1081     |
# |    total_timesteps  | 887736   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.9     |
# |    n_updates        | 209433   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9448     |
# |    fps              | 821      |
# |    time_elapsed     | 1081     |
# |    total_timesteps  | 888112   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.98     |
# |    n_updates        | 209527   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9452     |
# |    fps              | 821      |
# |    time_elapsed     | 1082     |
# |    total_timesteps  | 888488   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.08     |
# |    n_updates        | 209621   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9456     |
# |    fps              | 821      |
# |    time_elapsed     | 1082     |
# |    total_timesteps  | 888864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.39     |
# |    n_updates        | 209715   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9460     |
# |    fps              | 821      |
# |    time_elapsed     | 1083     |
# |    total_timesteps  | 889240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 209809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9464     |
# |    fps              | 821      |
# |    time_elapsed     | 1083     |
# |    total_timesteps  | 889616   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.26     |
# |    n_updates        | 209903   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9468     |
# |    fps              | 821      |
# |    time_elapsed     | 1083     |
# |    total_timesteps  | 889992   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.13     |
# |    n_updates        | 209997   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9472     |
# |    fps              | 821      |
# |    time_elapsed     | 1084     |
# |    total_timesteps  | 890368   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.2     |
# |    n_updates        | 210091   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9476     |
# |    fps              | 820      |
# |    time_elapsed     | 1084     |
# |    total_timesteps  | 890744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.05     |
# |    n_updates        | 210185   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9480     |
# |    fps              | 820      |
# |    time_elapsed     | 1085     |
# |    total_timesteps  | 891120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.47     |
# |    n_updates        | 210279   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9484     |
# |    fps              | 820      |
# |    time_elapsed     | 1086     |
# |    total_timesteps  | 891496   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.7      |
# |    n_updates        | 210373   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9488     |
# |    fps              | 820      |
# |    time_elapsed     | 1086     |
# |    total_timesteps  | 891872   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.68     |
# |    n_updates        | 210467   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9492     |
# |    fps              | 820      |
# |    time_elapsed     | 1087     |
# |    total_timesteps  | 892248   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.57     |
# |    n_updates        | 210561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9496     |
# |    fps              | 820      |
# |    time_elapsed     | 1087     |
# |    total_timesteps  | 892624   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.58     |
# |    n_updates        | 210655   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9500     |
# |    fps              | 820      |
# |    time_elapsed     | 1088     |
# |    total_timesteps  | 893000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.18     |
# |    n_updates        | 210749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9504     |
# |    fps              | 820      |
# |    time_elapsed     | 1088     |
# |    total_timesteps  | 893376   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.68     |
# |    n_updates        | 210843   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9508     |
# |    fps              | 820      |
# |    time_elapsed     | 1089     |
# |    total_timesteps  | 893752   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.68     |
# |    n_updates        | 210937   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9512     |
# |    fps              | 820      |
# |    time_elapsed     | 1089     |
# |    total_timesteps  | 894128   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.35     |
# |    n_updates        | 211031   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9516     |
# |    fps              | 820      |
# |    time_elapsed     | 1090     |
# |    total_timesteps  | 894504   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.7     |
# |    n_updates        | 211125   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 9520     |
# |    fps              | 820      |
# |    time_elapsed     | 1090     |
# |    total_timesteps  | 894880   |
# | train/              |          |
# ...
# |    n_updates        | 234155   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10500    |
# |    fps              | 817      |
# |    time_elapsed     | 1206     |
# |    total_timesteps  | 987000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.1     |
# |    n_updates        | 234249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10504    |
# |    fps              | 817      |
# |    time_elapsed     | 1207     |
# |    total_timesteps  | 987376   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.89     |
# |    n_updates        | 234343   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10508    |
# |    fps              | 817      |
# |    time_elapsed     | 1207     |
# |    total_timesteps  | 987752   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.26     |
# |    n_updates        | 234437   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10512    |
# |    fps              | 817      |
# |    time_elapsed     | 1208     |
# |    total_timesteps  | 988128   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.44     |
# |    n_updates        | 234531   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10516    |
# |    fps              | 817      |
# |    time_elapsed     | 1208     |
# |    total_timesteps  | 988504   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 13       |
# |    n_updates        | 234625   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10520    |
# |    fps              | 817      |
# |    time_elapsed     | 1209     |
# |    total_timesteps  | 988880   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.2     |
# |    n_updates        | 234719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10524    |
# |    fps              | 817      |
# |    time_elapsed     | 1209     |
# |    total_timesteps  | 989256   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 13.5     |
# |    n_updates        | 234813   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10528    |
# |    fps              | 817      |
# |    time_elapsed     | 1209     |
# |    total_timesteps  | 989632   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.92     |
# |    n_updates        | 234907   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10532    |
# |    fps              | 817      |
# |    time_elapsed     | 1210     |
# |    total_timesteps  | 990008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.67     |
# |    n_updates        | 235001   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10536    |
# |    fps              | 817      |
# |    time_elapsed     | 1210     |
# |    total_timesteps  | 990384   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.4     |
# |    n_updates        | 235095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10540    |
# |    fps              | 817      |
# |    time_elapsed     | 1211     |
# |    total_timesteps  | 990760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 13.3     |
# |    n_updates        | 235189   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10544    |
# |    fps              | 817      |
# |    time_elapsed     | 1211     |
# |    total_timesteps  | 991136   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.38     |
# |    n_updates        | 235283   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10548    |
# |    fps              | 817      |
# |    time_elapsed     | 1212     |
# |    total_timesteps  | 991512   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.67     |
# |    n_updates        | 235377   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10552    |
# |    fps              | 817      |
# |    time_elapsed     | 1213     |
# |    total_timesteps  | 991888   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.46     |
# |    n_updates        | 235471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10556    |
# |    fps              | 817      |
# |    time_elapsed     | 1213     |
# |    total_timesteps  | 992264   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.34     |
# |    n_updates        | 235565   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10560    |
# |    fps              | 817      |
# |    time_elapsed     | 1214     |
# |    total_timesteps  | 992640   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.81     |
# |    n_updates        | 235659   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10564    |
# |    fps              | 817      |
# |    time_elapsed     | 1214     |
# |    total_timesteps  | 993016   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.1      |
# |    n_updates        | 235753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10568    |
# |    fps              | 817      |
# |    time_elapsed     | 1215     |
# |    total_timesteps  | 993392   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.24     |
# |    n_updates        | 235847   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10572    |
# |    fps              | 817      |
# |    time_elapsed     | 1215     |
# |    total_timesteps  | 993768   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.08     |
# |    n_updates        | 235941   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10576    |
# |    fps              | 817      |
# |    time_elapsed     | 1216     |
# |    total_timesteps  | 994144   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 14       |
# |    n_updates        | 236035   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10580    |
# |    fps              | 817      |
# |    time_elapsed     | 1216     |
# |    total_timesteps  | 994520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.21     |
# |    n_updates        | 236129   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10584    |
# |    fps              | 817      |
# |    time_elapsed     | 1216     |
# |    total_timesteps  | 994896   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.07     |
# |    n_updates        | 236223   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10588    |
# |    fps              | 817      |
# |    time_elapsed     | 1217     |
# |    total_timesteps  | 995272   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.65     |
# |    n_updates        | 236317   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10592    |
# |    fps              | 817      |
# |    time_elapsed     | 1217     |
# |    total_timesteps  | 995648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.9     |
# |    n_updates        | 236411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10596    |
# |    fps              | 817      |
# |    time_elapsed     | 1218     |
# |    total_timesteps  | 996024   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.49     |
# |    n_updates        | 236505   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10600    |
# |    fps              | 817      |
# |    time_elapsed     | 1218     |
# |    total_timesteps  | 996400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.02     |
# |    n_updates        | 236599   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10604    |
# |    fps              | 817      |
# |    time_elapsed     | 1219     |
# |    total_timesteps  | 996776   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.03     |
# |    n_updates        | 236693   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10608    |
# |    fps              | 817      |
# |    time_elapsed     | 1219     |
# |    total_timesteps  | 997152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.83     |
# |    n_updates        | 236787   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10612    |
# |    fps              | 817      |
# |    time_elapsed     | 1220     |
# |    total_timesteps  | 997528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.14     |
# |    n_updates        | 236881   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10616    |
# |    fps              | 817      |
# |    time_elapsed     | 1220     |
# |    total_timesteps  | 997904   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.75     |
# |    n_updates        | 236975   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10620    |
# |    fps              | 817      |
# |    time_elapsed     | 1220     |
# |    total_timesteps  | 998280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.58     |
# |    n_updates        | 237069   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10624    |
# |    fps              | 817      |
# |    time_elapsed     | 1221     |
# |    total_timesteps  | 998656   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.76     |
# |    n_updates        | 237163   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10628    |
# |    fps              | 817      |
# |    time_elapsed     | 1221     |
# |    total_timesteps  | 999032   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 17.1     |
# |    n_updates        | 237257   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10632    |
# |    fps              | 817      |
# |    time_elapsed     | 1222     |
# |    total_timesteps  | 999408   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.39     |
# |    n_updates        | 237351   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 10636    |
# |    fps              | 817      |
# |    time_elapsed     | 1222     |
# |    total_timesteps  | 999784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.53     |
# |    n_updates        | 237445   |
# ----------------------------------

# %%
env = gym.make('stocks-v0', df=df, frame_bound=(200,250), window_size=5)
obs = env.reset()

# Unpack the tuple
array_obs, dict_obs = obs

# Add a new axis to the array part
array_obs = array_obs[np.newaxis, ...]

while True:
    obs = array_obs
    action, _states = model_DQN.predict(obs)
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    if done:
        print("info", info)
        break

plt.figure(figsize=(15,6))
plt.cla()
env.unwrapped.render_all()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# info {'total_reward': -0.019999980926513672, 'total_profit': 0.8948412157819589, 'position': <Positions.Long: 1>}
